# %% [markdown]
# # Analyse des Temps d'Opérations

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# B-tree en C

# %%
# Read the CSV file
data = pd.read_csv('complexite_temps_Btree.csv')

plt.figure(figsize=(18, 6))

# Graphique pour la recherche
plt.subplot(1, 3, 1)
plt.plot(data['Degrée'], data['Temps Recherche'], marker='o', label="Temps Recherche", color='blue')
plt.xlabel("Degrée")
plt.ylabel("Temps (ms)")
plt.title("Temps de Recherche")
plt.xscale("linear")
plt.yscale("linear")
plt.xticks(data['Degrée'], rotation=45)
plt.grid()
plt.legend()

# Graphique pour l'insertion
plt.subplot(1, 3, 2)
plt.plot(data['Degrée'], data['Temps Insertion'], marker='o', label="Temps Insertion", color='green')
plt.xlabel("Degrée")
plt.ylabel("Temps (s)")
plt.title("Temps d'Insertion")
plt.xscale("linear")
plt.yscale("linear")
plt.xticks(data['Degrée'], rotation=45)
plt.grid()
plt.legend()

# Graphique pour la suppression
plt.subplot(1, 3, 3)
plt.plot(data['Degrée'], data['Temps Suppression'], marker='o', label="Temps Suppression", color='red')
plt.xlabel("Degrée")
plt.ylabel("Temps (s)")
plt.title("Temps de Suppression")
plt.xscale("linear")
plt.yscale("linear")
plt.xticks(data['Degrée'], rotation=45)
plt.grid()
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# B-tree en C++

# %%
# Read the CSV file
data = pd.read_csv('complexite_temps_Btree_c++.csv')

plt.figure(figsize=(18, 6))

# Graphique pour la recherche
plt.subplot(1, 3, 1)
plt.plot(data['Degrée'], data['Temps Recherche'], marker='o', label="Temps Recherche", color='blue')
plt.xlabel("Degrée")
plt.ylabel("Temps (ms)")
plt.title("Temps de Recherche")
plt.xscale("linear")
plt.yscale("linear")
plt.xticks(data['Degrée'], rotation=45)
plt.grid()
plt.legend()

# Graphique pour l'insertion
plt.subplot(1, 3, 2)
plt.plot(data['Degrée'], data['Temps Insertion'], marker='o', label="Temps Insertion", color='green')
plt.xlabel("Degrée")
plt.ylabel("Temps (s)")
plt.title("Temps d'Insertion")
plt.xscale("linear")
plt.yscale("linear")
plt.xticks(data['Degrée'], rotation=45)
plt.grid()
plt.legend()

# Graphique pour la suppression
plt.subplot(1, 3, 3)
plt.plot(data['Degrée'], data['Temps Suppression'], marker='o', label="Temps Suppression", color='red')
plt.xlabel("Degrée")
plt.ylabel("Temps (s)")
plt.title("Temps de Suppression")
plt.xscale("linear")
plt.yscale("linear")
plt.xticks(data['Degrée'], rotation=45)
plt.grid()
plt.legend()

plt.tight_layout()
plt.show()
